# %%
import pandas as pd
 
import os

current_directory = os.getcwd()

df_US_OIL = pd.read_excel(current_directory+"\\US OIL Dataset.xlsx", sheet_name = 'Data 2')
# first we Focus with US_OIL
df_US_OIL.columns = df_US_OIL.iloc[1]
df_US_OIL = df_US_OIL[2:].reset_index(drop = True)
df_US_OIL['Date'] = pd.to_datetime(df_US_OIL['Date']).dt.strftime('%Y-%m')
#df_US_OIL = df_US_OIL[df_US_OIL['U.S. Ending Stocks of Crude Oil (Thousand Barrels)'].notna()]
df_US_OIL = df_US_OIL.fillna(0)
df_US_OIL
# Out:
# 1        Date  U.S. Field Production of Crude Oil (Thousand Barrels)  \
# 0     1920-01                                              34008
# 1     1920-02                                              33193
# 2     1920-03                                              36171
# 3     1920-04                                              34945
# 4     1920-05                                              36622
# ...       ...                                                ...
# 1239  2023-04                                             379500
# 1240  2023-05                                             393513
# 1241  2023-06                                             386834
# 1242  2023-07                                             401726
# 1243  2023-08                                             404637
#
# 1     U.S. Transfers to Crude Oil Supply of Crude Oil(Thousand Barrels)  \
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 1239                                              13873
# 1240                                              13376
# 1241                                              19028
# 1242                                              19118
# 1243                                              23491
#
# 1     U.S. Imports of Crude Oil (Thousand Barrels)  \
# 0                                             6294
# 1                                             4940
# 2                                             6503
# 3                                             6186
# 4                                             6966
# ...                                            ...
# 1239                                        185821
# 1240                                        200556
# 1241                                        194814
# 1242                                        194899
# 1243                                        217594
#
# 1     U.S. Supply Adjustment of Crude Oil (Thousand Barrels)  \
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 1239                                               3259
# 1240                                               4019
# 1241                                              -7515
# 1242                                               3020
# 1243                                             -19583
#
# 1     U.S. Crude Oil Stock Change (Thousand Barrels)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
# ...                                              ...
# 1239                                          -13007
# 1240                                           -8419
# 1241                                          -13294
# 1242                                          -14652
# 1243                                          -19611
#
# 1     U.S. Refinery and Blender Net Input of Crude Oil (Thousand Barrels)  \
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 1239                                             475195
# 1240                                             502416
# 1241                                             491836
# 1242                                             514541
# 1243                                             517364
#
# 1     U.S. Exports of Crude Oil (Thousand Barrels)  \
# 0                                              469
# 1                                              853
# 2                                              892
# 3                                              693
# 4                                              761
# ...                                            ...
# 1239                                        120265
# 1240                                        117467
# 1241                                        114618
# 1242                                        118874
# 1243                                        128386
#
# 1     U.S. Product Supplied of Crude Oil (Thousand Barrels)  \
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 1239                                                  0
# 1240                                                  0
# 1241                                                  0
# 1242                                                  0
# 1243                                                  0
#
# 1     U.S. Ending Stocks of Crude Oil (Thousand Barrels)
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 1239                                             823605
# 1240                                             815186
# 1241                                             801892
# 1242                                             787240
# 1243                                             767629
#
# [1244 rows x 10 columns]

# %%
print(df_US_OIL.columns)
df_US_OIL_Selected = df_US_OIL[['Date','U.S. Field Production of Crude Oil (Thousand Barrels)',
                                'U.S. Imports of Crude Oil (Thousand Barrels)', 'U.S. Exports of Crude Oil (Thousand Barrels)',
                                'U.S. Ending Stocks of Crude Oil (Thousand Barrels)']]
# Out:
# Index(['Date', 'U.S. Field Production of Crude Oil (Thousand Barrels)',
#        'U.S. Transfers to Crude Oil Supply of Crude Oil(Thousand Barrels)',
#        'U.S. Imports of Crude Oil (Thousand Barrels)',
#        'U.S. Supply Adjustment of Crude Oil (Thousand Barrels)',
#        'U.S. Crude Oil Stock Change (Thousand Barrels)',
#        'U.S. Refinery and Blender Net Input of Crude Oil (Thousand Barrels)',
#        'U.S. Exports of Crude Oil (Thousand Barrels)',
#        'U.S. Product Supplied of Crude Oil (Thousand Barrels)',
#        'U.S. Ending Stocks of Crude Oil (Thousand Barrels)'],
#       dtype='object', name=1)

# %%
df_US_OIL_Selected.info()
df_US_OIL_Selected.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1244 entries, 0 to 1243
# Data columns (total 5 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Date                                                   1244 non-null   object
#  1   U.S. Field Production of Crude Oil (Thousand Barrels)  1244 non-null   int64
#  2   U.S. Imports of Crude Oil (Thousand Barrels)           1244 non-null   int64
#  3   U.S. Exports of Crude Oil (Thousand Barrels)           1244 non-null   int64
#  4   U.S. Ending Stocks of Crude Oil (Thousand Barrels)     1244 non-null   int64
# dtypes: int64(4), object(1)
# memory usage: 48.7+ KB
# Index(['Date', 'U.S. Field Production of Crude Oil (Thousand Barrels)',
#        'U.S. Imports of Crude Oil (Thousand Barrels)',
#        'U.S. Exports of Crude Oil (Thousand Barrels)',
#        'U.S. Ending Stocks of Crude Oil (Thousand Barrels)'],
#       dtype='object', name=1)

# %%
df_US_OIL_Selected
# Out:
# 1        Date  U.S. Field Production of Crude Oil (Thousand Barrels)  \
# 0     1920-01                                              34008
# 1     1920-02                                              33193
# 2     1920-03                                              36171
# 3     1920-04                                              34945
# 4     1920-05                                              36622
# ...       ...                                                ...
# 1239  2023-04                                             379500
# 1240  2023-05                                             393513
# 1241  2023-06                                             386834
# 1242  2023-07                                             401726
# 1243  2023-08                                             404637
#
# 1     U.S. Imports of Crude Oil (Thousand Barrels)  \
# 0                                             6294
# 1                                             4940
# 2                                             6503
# 3                                             6186
# 4                                             6966
# ...                                            ...
# 1239                                        185821
# 1240                                        200556
# 1241                                        194814
# 1242                                        194899
# 1243                                        217594
#
# 1     U.S. Exports of Crude Oil (Thousand Barrels)  \
# 0                                              469
# 1                                              853
# 2                                              892
# 3                                              693
# 4                                              761
# ...                                            ...
# 1239                                        120265
# 1240                                        117467
# 1241                                        114618
# 1242                                        118874
# 1243                                        128386
#
# 1     U.S. Ending Stocks of Crude Oil (Thousand Barrels)
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 1239                                             823605
# 1240                                             815186
# 1241                                             801892
# 1242                                             787240
# 1243                                             767629
#
# [1244 rows x 5 columns]

# %%
df_inflation = pd.read_excel(current_directory+"\\Inflation table.xlsx")

df_inflation = df_inflation[df_inflation['Year'].notna()]
df_inflation.drop(columns=['Ave'],inplace =True)
df_inflation['Year'] = df_inflation['Year'].astype(int).astype(str)

df_inflation_melt = df_inflation.melt(id_vars='Year', var_name='Month', value_name='Value')
df_inflation_melt['Date'] = df_inflation_melt['Year'] + '-' + df_inflation_melt['Month']
df_inflation_melt.drop(columns=['Year', 'Month'],inplace = True)

df_inflation_melt['Date'] = pd.to_datetime(df_inflation_melt['Date']).dt.strftime('%Y-%m')
df_inflation_melt.dropna()
# Out:
#      Value     Date
# 0      2.0  1914-01
# 1      1.0  1915-01
# 2      3.0  1916-01
# 3     12.5  1917-01
# 4     19.7  1918-01
# ...    ...      ...
# 1314   1.9  2018-12
# 1315   2.3  2019-12
# 1316   1.4  2020-12
# 1317   7.0  2021-12
# 1318   6.5  2022-12
#
# [1319 rows x 2 columns]

# %%
df_DFF = pd.read_csv(current_directory+"\\DFF.csv")
df_DFF['DATE'] =  pd.to_datetime(df_DFF['DATE']).dt.strftime('%Y-%m')
df_DFF = df_DFF.groupby(['DATE'])['DFF'].mean().round(2).reset_index()

# %%
df_merged = df_DFF.merge(df_inflation_melt, left_on = 'DATE', right_on = 'Date', how = 'left')
df_merged = df_merged.merge(df_US_OIL_Selected, on= 'Date', how = 'left')
df_merged = df_merged.dropna().drop(columns = ['DATE']).rename(columns = {'Value' : 'U.S. Inflation', 'DFF' : 'Federal Fund Effective Rate (DFF)'})

# %%
df_merged.to_csv(current_directory+'\inflation DFF OIL.csv',index = False)
